# %% [markdown]
# # Topic ideas - Data
#
# ---
#
# Group name: Group D
#
# ---
#
# *Replace the italic texts with your descriptions*

# %% [markdown]
# ## Name of topic idea 1
#
# ### Data source
# https://data.europa.eu/data/datasets/3b960a00-4b5f-4e45-a149-5a048f7ee837-stadt-zurich?locale=en
# The data was collected weekly in 2019
#
#
# ### Data characterisitcs
#
# These data allow a very precise comparison between the planned (SOLL) and the effective (IST) driving times of each vehicle of the Verkehrsbetriebe Zürich (VBZ). The arrivals and departures of each vehicle on its line are measured in seconds.
#
# ### Question
#
# How can the traffic situation be improved in Zürich to ensure a more sustainable way of travelling during rush hours?
#
# ### Overview of data

# %%
import pandas as pd 
df = pd.read_csv('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2019/download/Fahrzeiten_SOLL_IST_20190203_20190209.csv')
df.head()
# Out:
#    linie  richtung betriebsdatum  fahrzeug  kurs  seq_von  halt_diva_von  \
# 0      2         1      03.02.19      2072     6        1           6030
# 1      2         1      03.02.19      3033     3        1            478
# 2      2         1      03.02.19      3033     3        5            601
# 3      2         1      03.02.19      3033     3        4           1861
# 4      2         1      03.02.19      3033     3        3           2396
#
#    halt_punkt_diva_von halt_kurz_von1 datum_von  ...  fahrweg_id  fw_no  \
# 0                    0           DEP4  03.02.19  ...       99439     15
# 1                    0           BEZI  03.02.19  ...      107009     11
# 2                    0           KANB  03.02.19  ...      107009     11
# 3                    0           PARA  03.02.19  ...      107009     11
# 4                    0           SIHS  03.02.19  ...      107009     11
#
#    fw_typ  fw_kurz                   fw_lang  umlauf_von  halt_id_von  \
# ...

# %% [markdown]
# ## Name of topic idea 2
#
# ### Data source
#
# https://data.europa.eu/data/datasets/22985306-bundesamt-fur-statistik-bfs?locale=de
# The data was collected yearly from 1980-2021
#
#
# ### Data characterisitcs
#
#  University degrees by university, department group, exam level, and gender.
#
# ### Question
#
# Is there a correlation between courses of study and gender between 1980 and 2021?
#
# ### Overview of data

# %%
df_2 = pd.read_csv('https://www.bfs.admin.ch/bfsstatic/dam/assets/22985307/master', delimiter=';')
df_2.head()
# Out:
#    PERIOD  UNI  FIELD  LEVEL  SEX  VALUE
# 0    1980    1      1      1    1     32
# 1    1980    1      1      1    2     22
# 2    1980    1      1      4    0      1
# 3    1980    1      1      4    1     11
# 4    1980    1      1      4    2      5
